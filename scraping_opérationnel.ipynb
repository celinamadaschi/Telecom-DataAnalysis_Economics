# %% [markdown]
# #### Fetching data

# %%
pip install pandas
pip install selenium
pip install BeautifulSoup4
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/isaureplt/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/isaureplt/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 9.6 MB/s  0:00:016m0:00:0100:01
# Downloading numpy-2.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 8.2 MB/s  0:00:01m0:00:01:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-2.4.0 pandas-2.3.3 pytz-2025.2 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import os
import pandas as pd
import requests
import string
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# --- SELENIUM IMPORTS ---
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager

# ---------------------------------------------------------
# CONFIGURATION
# ---------------------------------------------------------
BASE_URL = "https://econpapers.repec.org"
JEL_LETTERS = ["A", "B", "C"]   # test
LIMIT_PER_CATEGORY = 20

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "From": "researcher@university.edu"
}

# ---------------------------------------------------------
# SELENIUM — LIENS
# ---------------------------------------------------------
def get_links_with_selenium(jel_letter):

    options = webdriver.ChromeOptions()
    options.add_argument("--disable-gpu")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )

    paper_links = []

    url = (
        "https://econpapers.repec.org/scripts/search.pf"
        f"?jel={jel_letter}*&ni=10%20years&inpage=1000"
    )

    driver.get(url)
    wait = WebDriverWait(driver, 10)

    wait.until(EC.element_to_be_clickable(
        (By.XPATH, "//input[@type='SUBMIT']")
    )).click()

    Select(wait.until(
        EC.presence_of_element_located((By.ID, "inpage1"))
    )).select_by_value(str(LIMIT_PER_CATEGORY))

    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    links = []
    for a in soup.find_all("a", href=re.compile(r"/paper/|/article/")):
        href = a["href"]
        if "scripts" in href or "pers" in href:
            continue
        links.append(urljoin(BASE_URL, href))

    return list(dict.fromkeys(links))

# ---------------------------------------------------------
# SCRAPING MÉTADONNÉES
# ---------------------------------------------------------
def get_paper_details(url, jel_cat):

    try:
        soup = BeautifulSoup(
            requests.get(url, headers=HEADERS, timeout=10).text,
            "html.parser"
        )

        # --- TITRE ---
        title = soup.find("h1", class_="colored").get_text(strip=True)

        # --- ANNÉE ---
        year = None
        date = soup.find("b", string=re.compile("Date:"))
        if date:
            m = re.search(r"\d{4}", date.next_sibling or "")
            if m:
                year = int(m.group())

        # --- AUTEURS (SOURCE FIABLE) ---
        authors = [
            m["content"].replace(",", "")
            for m in soup.find_all("meta", {"name": "citation_author"})
        ]

        if not authors:
            authors = ["Voir texte"]
        # --- JOURNAL ---
        journal = None
        journal_meta = soup.find("meta", {"name": "citation_journal_title"})
        if journal_meta:
            journal = journal_meta.get("content", None)

        # --- AFFILIATIONS ---
        affil = soup.find("span", id="contact")
        affiliations = affil.get_text(" ", strip=True) if affil else None

        # --- TYPE ---
        pub_type = "Journal Article" if "/article/" in url else "Working Paper"

        return {
            "JEL Subject": jel_cat,
            "Title": title,
            "Author(s)": "; ".join(authors),
            "Journal": journal, 
            "Year": year,
            "Type": pub_type,
            "Affiliations": affiliations,
            "URL": url
        }

    except Exception:
        return None

# ---------------------------------------------------------
# MAIN
# ---------------------------------------------------------
def main(csv_filename):

    data = []

    for jel in JEL_LETTERS:
        links = get_links_with_selenium(jel)
        for link in links:
            d = get_paper_details(link, jel)
            if d:
                data.append(d)

    df = pd.DataFrame(data).drop_duplicates("URL")
    df.to_csv(csv_filename, index=False)

# ---------------------------------------------------------
# RUN
# ---------------------------------------------------------
if __name__ == "__main__":

    out = "RePEc_Final_Dataset_Corrected.csv"
    if os.path.exists(out):
        os.remove(out)

    main(out)

# %% [markdown]
# #### Data cleaning

# %%
df = pd.read_csv("RePEc_Final_Dataset_Corrected.csv")
import pandas as pd
import numpy as np

def clean_affiliation(text):
    if pd.isna(text):
        return np.nan
    
    # Si le format est "Auteur: Affiliation"
    if ":" in text:
        return text.split(":", 1)[1].strip()
    
    return text.strip()

df["Affiliations"] = df["Affiliations"].apply(clean_affiliation)
df = df.iloc[2:].reset_index(drop=True)
df.head(20)
# Out:
#    JEL Subject                                              Title  \
# 0            A  Preparing students for careers using business ...
# 1            A  Measuring Democracy - Eight indices: Polity, F...
# 2            A  Oeconstudiet og den ÃÂ¸konomiske faggruppe ve...
# 3            A  Digital Tools in the Educational Environment E...
# 4            A  On the Gender Diversity of Research Teams in E...
# 5            A  Messages That Foster a Sense of Belonging Impr...
# 6            A        Parenthood and Academic Career Trajectories
# 7            A  Impact versus Inclusion in the Economics Profe...
# 8            A  Teaching-Track Economists: A Canadian Perspective
# 9            A  Male Is a Gender, Too: A Review of Why Gender ...
# 10           A  Comments on Economic Models, Economics, and Ec...
# 11           A         Where Economics Went Wrong: A Review Essay
# 12           A  The Effect of Teaching Economics with Classroo...
# 13           A  Some Journal of Economic Perspectives Articles...
# 14           A  Lessons for Expanding the Share of Disadvantag...
# 15           A  Rational rollout of new medicines for diseases...
# 16           A                Understanding middle-class tax cuts
# 17           A  The candidates in their own words: A textual a...
# 18           A  Smoking out illicit trade: How some policies i...
# 19           A        Tax reform: Ryan-Brady plan is a better way
#
#                                             Author(s)  \
# 0                  Nielsen Erland Hejn; Nielsen Steen
# 1                                       Paldam Martin
# 2                                     Hylleberg Svend
# 3                                    Andra Diaconescu
# 4                                     Biermann Marcus
# 5                                  Forcada Sara Avila
# 6                    Lassen Anne Sophie; IvandiÄ Ria
# 7   Bansak Cynthia; Dunn Wendy; Meade Ellen; Starr...
# 8                         Murdock Jennifer; Cohen Avi
# 9                                        Nelson Julie
# 10                                   Rubinstein Ariel
# 11                                   Johnson Marianne
# 12  Gelfer Sacha; Livingston Jeffrey A.; Roy Sutanuka
# 13                                     Taylor Timothy
# 14                      Cook Lisa D.; Moser Christine
# 15                                         Bate Roger
# 16                                         Brill Alex
# 17                                      Zhong Weifeng
# 18                                         Bate Roger
# 19                                         Brill Alex
#
#                              Journal    Year             Type  \
# 0                                NaN  2020.0    Working Paper
# 1                                NaN  2021.0    Working Paper
# 2                                NaN  2023.0    Working Paper
# 3               Research & Education  2024.0  Journal Article
# 4         AEA Papers and Proceedings  2023.0  Journal Article
# 5         AEA Papers and Proceedings  2023.0  Journal Article
# 6         AEA Papers and Proceedings  2024.0  Journal Article
# 7         AEA Papers and Proceedings  2024.0  Journal Article
# 8         AEA Papers and Proceedings  2024.0  Journal Article
# 9     Journal of Economic Literature  2016.0  Journal Article
# 10    Journal of Economic Literature  2017.0  Journal Article
# 11    Journal of Economic Literature  2020.0  Journal Article
# 12        AEA Papers and Proceedings  2022.0  Journal Article
# 13  Journal of Economic Perspectives  2019.0  Journal Article
# 14  Journal of Economic Perspectives  2024.0  Journal Article
# 15         AEI Economic Perspectives  2015.0  Journal Article
# 16         AEI Economic Perspectives  2016.0  Journal Article
# 17         AEI Economic Perspectives  2016.0  Journal Article
# 18         AEI Economic Perspectives  2016.0  Journal Article
# 19         AEI Economic Perspectives  2016.0  Journal Article
#
#                                          Affiliations  \
# 0   Department of Economics and Business Economics...
# 1   Department of Economics and Business Economics...
# 2   Department of Economics and Business Economics...
# 3   Politehnica University of Timisoara, Faculty o...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                      American Enterprise Institute
# 16                                                NaN
# 17                                                NaN
# 18                      American Enterprise Institute
# 19                                                NaN
#
#                                                   URL
# 0   https://econpapers.repec.org/paper/aahaarhec/2...
# 1   https://econpapers.repec.org/paper/aahaarhec/2...
# 2   https://econpapers.repec.org/paper/aahaarhec/2...
# 3   https://econpapers.repec.org/article/aaijournl...
# 4   https://econpapers.repec.org/article/aeaapandp...
# 5   https://econpapers.repec.org/article/aeaapandp...
# 6   https://econpapers.repec.org/article/aeaapandp...
# 7   https://econpapers.repec.org/article/aeaapandp...
# 8   https://econpapers.repec.org/article/aeaapandp...
# 9   https://econpapers.repec.org/article/aeajeclit...
# 10  https://econpapers.repec.org/article/aeajeclit...
# 11  https://econpapers.repec.org/article/aeajeclit...
# 12  https://econpapers.repec.org/article/aeaapandp...
# 13  https://econpapers.repec.org/article/aeajecper...
# 14  https://econpapers.repec.org/article/aeajecper...
# 15  https://econpapers.repec.org/article/aeijournl...
# 16  https://econpapers.repec.org/article/aeijournl...
# 17  https://econpapers.repec.org/article/aeijournl...
# 18  https://econpapers.repec.org/article/aeijournl...
# 19  https://econpapers.repec.org/article/aeijournl...

# %%
df.iloc[14,7]
# Out:
# 'https://econpapers.repec.org/article/aeajecper/v_3a38_3ay_3a2024_3ai_3a3_3ap_3a191-208.htm'

# %%
import requests

url = 'http://ideas.repec.org/e/pal184.html'
html = requests.get(url).text

with open("author_page_debug.html", "w", encoding="utf-8") as f:
    f.write(html)

print("HTML auteur sauvegardé")
# Out:
# HTML auteur sauvegardé

# %%
if __name__ == "__main__":
    df_authors = scrape_author_index(max_authors=20)
    print("Authors found:", len(df_authors))

    df_affil = build_author_affiliation_table(df_authors)
    df_affil.to_csv("RePEc_Author_Affiliations_TEST20.csv", index=False)

    print("Saved author affiliations (TEST 20)")
# Out:
# Authors found: 20
# Saved author affiliations (TEST 20)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

BASE_URL = "https://ideas.repec.org"
INDEX_URL = "https://ideas.repec.org/i/eall.html"
LETTERS = ["A", "B", "C"]  # test A-C
HEADERS = {"User-Agent": "Mozilla/5.0"}


# -------------------------------------------------
# 1. Scrape author index
# -------------------------------------------------
def scrape_author_index(max_authors=None):
    resp = requests.get(INDEX_URL, headers=HEADERS)
    resp.raise_for_status()

    soup = BeautifulSoup(resp.text, "html.parser")
    authors = []

    for letter in LETTERS:
        anchor = soup.find("a", {"name": letter})
        if not anchor:
            continue

        table = anchor.find_next("table")
        if not table:
            continue

        for a in table.find_all("a", href=True):
            href = a["href"]

            if not href.endswith(".html"):
                continue

            author_name = a.get_text(strip=True)
            author_url = urljoin(BASE_URL, href)
            short_id = href.split("/")[-1].replace(".html", "")

            authors.append({
                "author_name": author_name,
                "short_id": short_id,
                "author_url": author_url
            })

            if max_authors and len(authors) >= max_authors:
                return pd.DataFrame(authors)

    return pd.DataFrame(authors)


# -------------------------------------------------
# 2. Scrape affiliation from author page
# -------------------------------------------------
def scrape_author_affiliation(author_url):
    try:
        resp = requests.get(author_url, headers=HEADERS, timeout=10)
        resp.raise_for_status()
    except Exception:
        return {
            "institution": None,
            "location": None,
            "repec_institution_id": None
        }

    soup = BeautifulSoup(resp.text, "html.parser")

    aff_div = soup.find("div", id="affiliation")
    if not aff_div:
        return {
            "institution": None,
            "location": None,
            "repec_institution_id": None
        }

    institution = None
    location = None
    repec_id = None

    h3 = aff_div.find("h3")
    if h3:
        institution = h3.get_text(strip=True)

    loc = aff_div.find("span", class_="locationlabel")
    if loc:
        location = loc.get_text(strip=True)

    handle = aff_div.find("span", class_="handlelabel")
    if handle:
        repec_id = handle.get_text(strip=True).replace("RePEc:", "")

    return {
        "institution": institution,
        "location": location,
        "repec_institution_id": repec_id
    }


# -------------------------------------------------
# 3. Build affiliation table
# -------------------------------------------------
def build_author_affiliation_table(df_authors, sleep_time=1):
    rows = []

    for i, row in df_authors.iterrows():
        print(f"[{i+1}/{len(df_authors)}] Scraping {row['author_name']}")

        aff = scrape_author_affiliation(row["author_url"])

        rows.append({
            "author_name": row["author_name"],
            "short_id": row["short_id"],
            "institution": aff["institution"],
            "location": aff["location"],
            "repec_institution_id": aff["repec_institution_id"],
            "author_url": row["author_url"]
        })

        time.sleep(sleep_time)  # IMPORTANT pour RePEc

    return pd.DataFrame(rows)


# -------------------------------------------------
# 4. Main
# -------------------------------------------------
if __name__ == "__main__":
    df_authors = scrape_author_index(max_authors=20)
    print("Authors found:", len(df_authors))

    df_affil = build_author_affiliation_table(df_authors)
    df_affil.to_csv("RePEc_Author_Affiliations_TEST20.csv", index=False)

    print("Saved author affiliations (TEST 20)")
# Out:
# Authors found: 20
# [1/20] Scraping A, Arun Kumar
# [2/20] Scraping Alamri, Yosef A.
# [3/20] Scraping Antelius, Jesper
# [4/20] Scraping A, Selvarasu
# [5/20] Scraping Alan, Sule
# [6/20] Scraping Antell, Jan Wilhelm
# [7/20] Scraping Aaberge, Rolf
# [8/20] Scraping Alananga, Samwel Sanga
# [9/20] Scraping Antelo, Manel
# [10/20] Scraping Aad, Samar S
# [11/20] Scraping Alani, Ezekiel Ayinde
# [12/20] Scraping Antenord, Jean-Baptiste
# [13/20] Scraping Aadland, David
# [14/20] Scraping Alao, Abdul-Azeez Adeniyi
# [15/20] Scraping Anthoff, David
# [16/20] Scraping Aakvik, Arild
# [17/20] Scraping Alaoui, Larbi
# [18/20] Scraping Anthony, Johnson Ukwumonu
# [19/20] Scraping Aalbers, Rob
# [20/20] Scraping Alarcon, David
# Saved author affiliations (TEST 20)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

BASE_URL = "https://ideas.repec.org"
INDEX_URL = "https://ideas.repec.org/i/eall.html"
LETTERS = ["A", "B", "C"]  # test A-C
HEADERS = {"User-Agent": "Mozilla/5.0"}

# -------------------------------------------------
# 1. Scrape author index
# -------------------------------------------------
def scrape_author_index(max_authors=None):
    resp = requests.get(INDEX_URL, headers=HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    authors = []

    for letter in LETTERS:
        anchor = soup.find("a", {"name": letter})
        if not anchor:
            continue

        table = anchor.find_next("table")
        if not table:
            continue

        for a in table.find_all("a", href=True):
            href = a["href"]
            if not href.endswith(".html"):
                continue

            author_name = a.get_text(strip=True)
            author_url = urljoin(BASE_URL, href)
            short_id = href.split("/")[-1].replace(".html", "")

            authors.append({
                "author_name": author_name,
                "short_id": short_id,
                "author_url": author_url
            })

            if max_authors and len(authors) >= max_authors:
                return pd.DataFrame(authors)

    return pd.DataFrame(authors)

# -------------------------------------------------
# 2. Scrape ALL affiliations from author page
# -------------------------------------------------
def scrape_author_affiliations(author_url):
    try:
        resp = requests.get(author_url, headers=HEADERS, timeout=10)
        resp.raise_for_status()
    except Exception:
        return []

    soup = BeautifulSoup(resp.text, "html.parser")
    aff_div = soup.find("div", id="affiliation")

    if not aff_div:
        return []

    affiliations = []
    h3_blocks = aff_div.find_all("h3")

    for h3 in h3_blocks:
        institution_text = " ".join(h3.stripped_strings)

        # extract percentage if present
        share_pct = None
        if institution_text.startswith("("):
            share_pct = institution_text.split(")")[0].replace("(", "").strip()
            institution_text = institution_text.split(")", 1)[1].strip()

        location = None
        repec_id = None

        for sib in h3.find_next_siblings():
            if sib.name == "h3":
                break
            if sib.name == "span" and "locationlabel" in sib.get("class", []):
                location = sib.get_text(strip=True)
            if sib.name == "span" and "handlelabel" in sib.get("class", []):
                repec_id = sib.get_text(strip=True).replace("RePEc:", "")

        affiliations.append({
            "institution": institution_text,
            "share_pct": share_pct,
            "location": location,
            "repec_institution_id": repec_id
        })

    return affiliations

# -------------------------------------------------
# 3. Build affiliation table (LONG FORMAT)
# -------------------------------------------------
def build_author_affiliation_table(df_authors, sleep_time=1):
    rows = []

    for i, row in df_authors.iterrows():
        print(f"[{i+1}/{len(df_authors)}] Scraping {row['author_name']}")

        affils = scrape_author_affiliations(row["author_url"])

        # if no affiliation found, still keep author
        if not affils:
            rows.append({
                "author_name": row["author_name"],
                "short_id": row["short_id"],
                "institution": None,
                "share_pct": None,
                "location": None,
                "repec_institution_id": None,
                "author_url": row["author_url"]
            })
        else:
            for aff in affils:
                rows.append({
                    "author_name": row["author_name"],
                    "short_id": row["short_id"],
                    "institution": aff["institution"],
                    "share_pct": aff["share_pct"],
                    "location": aff["location"],
                    "repec_institution_id": aff["repec_institution_id"],
                    "author_url": row["author_url"]
                })

        time.sleep(sleep_time)  # IMPORTANT pour RePEc

    return pd.DataFrame(rows)

# -------------------------------------------------
# 4. Main
# -------------------------------------------------
if __name__ == "__main__":
    df_authors = scrape_author_index(max_authors=20)
    print("Authors found:", len(df_authors))

    df_affil = build_author_affiliation_table(df_authors)
    df_affil.to_csv("RePEc_Author_Affiliations_TEST20.csv", index=False)

    print("Saved author affiliations (TEST 20)")
# Out:
# Authors found: 20
# [1/20] Scraping A, Arun Kumar
# [2/20] Scraping Alamri, Yosef A.
# [3/20] Scraping Antelius, Jesper
# [4/20] Scraping A, Selvarasu
# [5/20] Scraping Alan, Sule
# [6/20] Scraping Antell, Jan Wilhelm
# [7/20] Scraping Aaberge, Rolf
# [8/20] Scraping Alananga, Samwel Sanga
# [9/20] Scraping Antelo, Manel
# [10/20] Scraping Aad, Samar S
# [11/20] Scraping Alani, Ezekiel Ayinde
# [12/20] Scraping Antenord, Jean-Baptiste
# [13/20] Scraping Aadland, David
# [14/20] Scraping Alao, Abdul-Azeez Adeniyi
# [15/20] Scraping Anthoff, David
# [16/20] Scraping Aakvik, Arild
# [17/20] Scraping Alaoui, Larbi
# [18/20] Scraping Anthony, Johnson Ukwumonu
# [19/20] Scraping Aalbers, Rob
# [20/20] Scraping Alarcon, David
# Saved author affiliations (TEST 20)

# %%
df_affil
# Out:
#                   author_name short_id  \
# 0               A, Arun Kumar    paa30
# 1            Alamri, Yosef A.   pal932
# 2            Antelius, Jesper   pan241
# 3                A, Selvarasu   pmu263
# 4                  Alan, Sule   pal184
# 5                  Alan, Sule   pal184
# 6                  Alan, Sule   pal184
# 7         Antell, Jan Wilhelm   pan150
# 8               Aaberge, Rolf     paa6
# 9               Aaberge, Rolf     paa6
# 10     Alananga, Samwel Sanga   pal927
# 11              Antelo, Manel   pan291
# 12               Aad, Samar S    paa32
# 13      Alani, Ezekiel Ayinde   pal978
# 14    Antenord, Jean-Baptiste   pan582
# 15             Aadland, David     paa2
# 16  Alao, Abdul-Azeez Adeniyi  pal1218
# 17             Anthoff, David   pan171
# 18              Aakvik, Arild     paa1
# 19              Alaoui, Larbi   pal299
# 20  Anthony, Johnson Ukwumonu   pan647
# 21               Aalbers, Rob     paa8
# 22             Alarcon, David   pal784
#
#                                           institution share_pct  \
# 0           The ICFAI Foundation for Higher Education       50%
# 1   Department of Agricultural Economics Universit...      None
# 2                 Riksrevisionen Government of Sweden      None
# 3   Department of Business Administration Annamala...      None
# 4   Department of Economics European University In...       73%
# 5                 İktisat Bölümü Bilkent Üniversitesi       23%
# 6   Abdul Latif Jameel Poverty Action Lab (J-PAL) ...        4%
# 7                     Hanken Svenska Handelshögskolan      None
# 8         Statistisk Sentralbyrå Government of Norway       20%
# 9            Økonomisk institutt Universitetet i Oslo       80%
# 10  Ardhi Univeristy, Department of Land Managemen...      None
# 11  Departamento de Fundamentos da Análise Económi...      None
# 12  Adnan Kassar School of Business Lebanese Ameri...      None
# 13  Department of Agricultural Economics and Exten...      None
# 14                 Lille Économie et Management (LEM)      None
# 15  Department of Economics College of Business Un...      None
# 16                                               None      None
# 17  University of California-Berkeley, Energy and ...      None
# 18       Institutt for Økonomi Universitetet i Bergen      None
# 19  Departament d'Economia i Empresa Universitat P...      None
# 20  Federal College of Education (Federal College ...      None
# 21  Centraal Planbureau (CPB) Government of the Ne...      None
# 22                                               None      None
#
#                                     location repec_institution_id  \
# 0                                  Hyderabad                 None
# 1        Lexington, Kentucky (United States)          edi:daukyus
# 2                          Stockholm, Sweden          edi:srrgvse
# 3                     Annamalai Nagar, India          edi:dbannin
# 4                             Firenze, Italy          edi:deiueit
# 5                             Ankara, Turkey          edi:debiltr
# 6   Cambridge, Massachusetts (United States)          edi:jpmitus
# 7                          Helsinki, Finland          edi:shhhhfi
# 8                               Oslo, Norway          edi:ssbgvno
# 9                               Oslo, Norway          edi:souiono
# 10                   Tanzania, Dar es Salaam                 None
# 11             Santiago de Compostela, Spain          edi:dfusces
# 12                    Beirut/Byblos, Lebanon          edi:sblaulb
# 13                         Ogbomoso, Nigeria          edi:dalaung
# 14                             Lille, France          edi:laborfr
# 15          Laramie, Wyoming (United States)          edi:deuwyus
# 16                                      None                 None
# 17                         Berkeley, CA, USA                 None
# 18                            Bergen, Norway          edi:iouibno
# 19                          Barcelona, Spain          edi:deupfes
# 20                             Nigeria, Yola                 None
# 21                     Den Haag, Netherlands          edi:cpbgvnl
# 22                                      None                 None
#
#                                 author_url
# 0     https://ideas.repec.org/e/paa30.html
# 1    https://ideas.repec.org/f/pal932.html
# 2    https://ideas.repec.org/f/pan241.html
# 3    https://ideas.repec.org/f/pmu263.html
# 4    https://ideas.repec.org/e/pal184.html
# 5    https://ideas.repec.org/e/pal184.html
# 6    https://ideas.repec.org/e/pal184.html
# 7    https://ideas.repec.org/e/pan150.html
# 8      https://ideas.repec.org/e/paa6.html
# 9      https://ideas.repec.org/e/paa6.html
# 10   https://ideas.repec.org/f/pal927.html
# 11   https://ideas.repec.org/f/pan291.html
# 12    https://ideas.repec.org/e/paa32.html
# 13   https://ideas.repec.org/f/pal978.html
# 14   https://ideas.repec.org/f/pan582.html
# 15     https://ideas.repec.org/e/paa2.html
# 16  https://ideas.repec.org/f/pal1218.html
# 17   https://ideas.repec.org/e/pan171.html
# 18     https://ideas.repec.org/e/paa1.html
# 19   https://ideas.repec.org/f/pal299.html
# 20   https://ideas.repec.org/f/pan647.html
# 21     https://ideas.repec.org/e/paa8.html
# 22   https://ideas.repec.org/f/pal784.html

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

BASE_URL = "https://ideas.repec.org"
INDEX_URL = "https://ideas.repec.org/i/eall.html"
LETTERS = ["A", "B", "C"]  # test A–C
HEADERS = {"User-Agent": "Mozilla/5.0"}

# -------------------------------------------------
# UE country codes in EDIRC (suffix)
# -------------------------------------------------
UE_COUNTRY_CODES = [
    "at", "be", "bg", "hr", "cy", "cz", "dk", "ee", "fi", "fr",
    "de", "gr", "hu", "ie", "it", "lv", "lt", "lu", "mt", "nl",
    "pl", "pt", "ro", "sk", "si", "es", "se"
]

def is_ue_edi(repec_id):
    """
    EDIRC ids look like edi:deiueit, edi:debiltr, etc.
    We check the last 2 letters = country code
    """
    if not repec_id:
        return False
    code = repec_id.lower()[-2:]
    return code in UE_COUNTRY_CODES

# -------------------------------------------------
# 1. Scrape author index
# -------------------------------------------------
def scrape_author_index():
    resp = requests.get(INDEX_URL, headers=HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    authors = []

    for letter in LETTERS:
        anchor = soup.find("a", {"name": letter})
        if not anchor:
            continue

        table = anchor.find_next("table")
        if not table:
            continue

        for a in table.find_all("a", href=True):
            href = a["href"]
            if not href.endswith(".html"):
                continue

            authors.append({
                "author_name": a.get_text(strip=True),
                "short_id": href.split("/")[-1].replace(".html", ""),
                "author_url": urljoin(BASE_URL, href)
            })

    return authors

# -------------------------------------------------
# 2. Scrape ALL affiliations
# -------------------------------------------------
def scrape_author_affiliations(author_url):
    try:
        resp = requests.get(author_url, headers=HEADERS, timeout=10)
        resp.raise_for_status()
    except Exception:
        return []

    soup = BeautifulSoup(resp.text, "html.parser")
    aff_div = soup.find("div", id="affiliation")

    if not aff_div:
        return []

    affiliations = []

    for h3 in aff_div.find_all("h3"):
        institution = " ".join(h3.stripped_strings)

        share_pct = None
        if institution.startswith("("):
            share_pct = institution.split(")")[0].replace("(", "").strip()
            institution = institution.split(")", 1)[1].strip()

        location = None
        repec_id = None

        for sib in h3.find_next_siblings():
            if sib.name == "h3":
                break
            if sib.name == "span" and "locationlabel" in sib.get("class", []):
                location = sib.get_text(strip=True)
            if sib.name == "span" and "handlelabel" in sib.get("class", []):
                repec_id = sib.get_text(strip=True).replace("RePEc:", "")

        affiliations.append({
            "institution": institution,
            "share_pct": share_pct,
            "location": location,
            "repec_institution_id": repec_id
        })

    return affiliations

# -------------------------------------------------
# 3. MAIN – EDIRC-FIRST TEST (20 UE AUTHORS)
# -------------------------------------------------
if __name__ == "__main__":

    authors = scrape_author_index()

    rows = []
    ue_authors_seen = set()

    for i, author in enumerate(authors):
        print(f"[{i+1}] Checking {author['author_name']}")

        affils = scrape_author_affiliations(author["author_url"])

        # keep only UE affiliations (EDIRC-based)
        affils_ue = [
            a for a in affils if is_ue_edi(a["repec_institution_id"])
        ]

        if not affils_ue:
            time.sleep(0.5)
            continue

        # add ALL UE affiliations for this author
        for aff in affils_ue:
            rows.append({
                "author_name": author["author_name"],
                "short_id": author["short_id"],
                "institution": aff["institution"],
                "share_pct": aff["share_pct"],
                "location": aff["location"],
                "repec_institution_id": aff["repec_institution_id"],
                "author_url": author["author_url"]
            })

        ue_authors_seen.add(author["short_id"])

        if len(ue_authors_seen) >= 20:
            print("Reached 20 UE authors – STOP")
            break

        time.sleep(0.5)

    df_test = pd.DataFrame(rows)
    df_test.to_csv("RePEc_UE_EDIRC_TEST20.csv", index=False)

    print("Saved RePEc_UE_EDIRC_TEST20.csv")
# Out:
# [1] Checking A, Arun Kumar
# [2] Checking Alamri, Yosef A.
# [3] Checking Antelius, Jesper
# [4] Checking A, Selvarasu
# [5] Checking Alan, Sule
# [6] Checking Antell, Jan Wilhelm
# [7] Checking Aaberge, Rolf
# [8] Checking Alananga, Samwel Sanga
# [9] Checking Antelo, Manel
# [10] Checking Aad, Samar S
# [11] Checking Alani, Ezekiel Ayinde
# [12] Checking Antenord, Jean-Baptiste
# [13] Checking Aadland, David
# [14] Checking Alao, Abdul-Azeez Adeniyi
# [15] Checking Anthoff, David
# [16] Checking Aakvik, Arild
# [17] Checking Alaoui, Larbi
# [18] Checking Anthony, Johnson Ukwumonu
# [19] Checking Aalbers, Rob
# [20] Checking Alarcon, David
# [21] Checking Anthony-Orji, Onyinye Imelda
# [22] Checking Aalto, Aino-Maija
# [23] Checking Alarcon, Jorge Victor
# [24] Checking Anthropelos, Michail
# [25] Checking Aamir, Suhaib
# [26] Checking Alarcon, Pedro
# [27] Checking Antigo, Mariangela Furlan
# [28] Checking Aamir Khan, Muhammad
# [29] Checking Alarcon Gambarte, Samuel
# [30] Checking Antimiani, Alessandro
# [31] Checking Aanderud, Philip
# [32] Checking Alarcon-Garcia, Gloria
# [33] Checking Antinolfi, Gaetano
# [34] Checking Aaron, Henry J.
# [35] Checking Alarcon Osuna, Moises Alejandro
# [36] Checking Antinyan, Armenak
# [37] Checking Aaronson, Daniel
# [38] Checking Alarcon Rodriguez, Arturo Daniel
# [39] Checking Antipa, Pamfili
# [40] Checking Aaronson, Susan Ariel
# [41] Checking Alarco Tosoni, German
# [42] Checking Antipina, Olga N.
# [43] Checking Aas, Eline
# [44] Checking Al Arif, Mohammad Nur Rianto
# [45] Checking Antipov, Evgeny
# [46] Checking Aas, Oyvind Nilsen
# [47] Checking Alarik, Bjorn
# [48] Checking Antle, John M.
# [49] Checking Aase, Knut Kristian
# [50] Checking Alary, David
# [51] Checking Antman, Francisca M.
# [52] Checking Aassve, Arnstein
# [53] Checking Al-Assaf, Ghazi
# [54] Checking Antoci, Angelo
# [55] Checking Aastveit, Knut Are
# [56] Checking Alatas, Vivi
# [57] Checking Antoine, Bertille
# [58] Checking Abad, Arnaud
# [59] Checking Alati, Andrea
# [60] Checking Antolin, Pablo
# [61] Checking Abad, Cristina
# [62] Checking Alauddin, Mohammad
# [63] Checking Antolin-Diaz, Juan
# [64] Checking Abad, Jorge
# ✅ Reached 20 UE authors – STOP
# Saved RePEc_UE_EDIRC_TEST20.csv

# %%
df_test
# Out:
#                 author_name short_id  \
# 0          Antelius, Jesper   pan241
# 1                Alan, Sule   pal184
# 2       Antell, Jan Wilhelm   pan150
# 3             Antelo, Manel   pan291
# 4   Antenord, Jean-Baptiste   pan582
# 5             Alaoui, Larbi   pal299
# 6              Aalbers, Rob     paa8
# 7         Aalto, Aino-Maija    paa28
# 8         Aalto, Aino-Maija    paa28
# 9      Anthropelos, Michail   pan319
# 10    Antimiani, Alessandro   pan258
# 11   Alarcon-Garcia, Gloria   pal382
# 12          Antipa, Pamfili   pan377
# 13          Antipa, Pamfili   pan377
# 14            Alarik, Bjorn   pal498
# 15             Alary, David   pal393
# 16     Antman, Francisca M.   pan425
# 17           Antoci, Angelo   pan233
# 18           Antoci, Angelo   pan233
# 19             Abad, Arnaud   pab453
# 20           Antolin, Pablo     pan8
# 21           Antolin, Pablo     pan8
# 22           Abad, Cristina   pab280
# 23              Abad, Jorge   pab367
#
#                                           institution share_pct  \
# 0                 Riksrevisionen Government of Sweden      None
# 1   Department of Economics European University In...       73%
# 2                     Hanken Svenska Handelshögskolan      None
# 3   Departamento de Fundamentos da Análise Económi...      None
# 4                  Lille Économie et Management (LEM)      None
# 5   Departament d'Economia i Empresa Universitat P...      None
# 6   Centraal Planbureau (CPB) Government of the Ne...      None
# 7   Nationalekonomi Fakulteten för Samhällsvetensk...       50%
# 8   Institutet för Social Forskning (SOFI) Stockho...       50%
# 9   Department of Banking and Financial Management...      None
# 10      Directorate-General Trade European Commission      None
# 11  Facultad de Economía y Empresa Universidad de ...      None
# 12                                   Banque de France       80%
# 13                   Sciences économiques Sciences Po       20%
# 14             Handelshögskolan Göteborgs Universitet      None
# 15  Laboratoire d'Économie des Ressources Naturell...      None
# 16                 Institute of Labor Economics (IZA)        5%
# 17                  Centro Ricerche Nord Sud (CRENoS)       40%
# 18  Dipartimento di Scienze Economiche e Aziendali...       60%
# 19    Bureau d'Économie Théorique et Appliquée (BETA)      None
# 20  Directorate for Financial, Fiscal and Enterpri...       50%
# 21  Economics Department Organisation de Coopérati...       35%
# 22  Facultad de Ciencias Económicas y Empresariale...      None
# 23                                    Banco de España      None
#
#                          location repec_institution_id  \
# 0               Stockholm, Sweden          edi:srrgvse
# 1                  Firenze, Italy          edi:deiueit
# 2               Helsinki, Finland          edi:shhhhfi
# 3   Santiago de Compostela, Spain          edi:dfusces
# 4                   Lille, France          edi:laborfr
# 5                Barcelona, Spain          edi:deupfes
# 6           Den Haag, Netherlands          edi:cpbgvnl
# 7                  Turku, Finland          edi:niabofi
# 8               Stockholm, Sweden          edi:sofsuse
# 9                 Piraeus, Greece          edi:dfpirgr
# 10     Bruxelles/Brussel, Belgium          edi:dgtecbe
# 11                  Murcia, Spain          edi:fcmures
# 12                  Paris, France          edi:bdfgvfr
# 13                  Paris, France          edi:ecspofr
# 14               Göteborg, Sweden          edi:hhsguse
# 15               Toulouse, France          edi:lrtlsfr
# 16                  Bonn, Germany          edi:izaaade
# 17                Cagliari, Italy          edi:crenoit
# 18                 Sassari, Italy          edi:disasit
# 19       Nancy/Strasbourg, France          edi:bestrfr
# 20                  Paris, France          edi:caoecfr
# 21                  Paris, France          edi:edoecfr
# 22                 Sevilla, Spain          edi:fcseves
# 23                  Madrid, Spain          edi:bdegves
#
#                                author_url
# 0   https://ideas.repec.org/f/pan241.html
# 1   https://ideas.repec.org/e/pal184.html
# 2   https://ideas.repec.org/e/pan150.html
# 3   https://ideas.repec.org/f/pan291.html
# 4   https://ideas.repec.org/f/pan582.html
# 5   https://ideas.repec.org/f/pal299.html
# 6     https://ideas.repec.org/e/paa8.html
# 7    https://ideas.repec.org/e/paa28.html
# 8    https://ideas.repec.org/e/paa28.html
# 9   https://ideas.repec.org/f/pan319.html
# 10  https://ideas.repec.org/f/pan258.html
# 11  https://ideas.repec.org/f/pal382.html
# 12  https://ideas.repec.org/f/pan377.html
# 13  https://ideas.repec.org/f/pan377.html
# 14  https://ideas.repec.org/f/pal498.html
# 15  https://ideas.repec.org/f/pal393.html
# 16  https://ideas.repec.org/f/pan425.html
# 17  https://ideas.repec.org/f/pan233.html
# 18  https://ideas.repec.org/f/pan233.html
# 19  https://ideas.repec.org/f/pab453.html
# 20    https://ideas.repec.org/e/pan8.html
# 21    https://ideas.repec.org/e/pan8.html
# 22  https://ideas.repec.org/f/pab280.html
# 23  https://ideas.repec.org/f/pab367.html
