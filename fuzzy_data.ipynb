# %%
import pandas as pd
from rapidfuzz import process, fuzz
import re
import unicodedata

# %%
#Load the two datasets 
df_Authors=pd.read_csv("data_A_Z.csv")
df_A_B_Code=pd.read_csv("RePEc_Full_A_B.csv")

# %%
#Identify Na authors and drop them 
sum(df_A_B_Code["Author(s)"].isna())
df_A_B_Code = df_A_B_Code.dropna(subset=["Author(s)"])

# %%
#Split authors by ;
#Duplicate the row for each author for the specific paper
df_A_B_Code = (
    df_A_B_Code
        .assign(**{
            "Author(s)": df_A_B_Code["Author(s)"].str.split(";")
        })
        .explode("Author(s)")
        .assign(**{
            "Author(s)": lambda x: x["Author(s)"].str.strip()
        })
        .reset_index(drop=True)
)

# %%
def strip_accents(s: str) -> str:
    s = unicodedata.normalize("NFKD", s)
    return "".join(ch for ch in s if not unicodedata.combining(ch))

def normalize_whitespace(s: str) -> str:
    return re.sub(r"\s+", " ", s).strip()

def standardize_name(raw):
    """
    Returns a cleaned full-name string with consistent formatting.
    Handles:
      - casefold/lowercase
      - accents removed
      - punctuation removed
      - 'Last, First' -> 'First Last'
      - extra spaces collapsed
    """
    if pd.isna(raw):
        return ""

    s = str(raw).strip()
    if s == "":
        return ""

    s = strip_accents(s).lower()

    # Convert "Last, First Middle" -> "First Middle Last"
    if "," in s:
        parts = [p.strip() for p in s.split(",", 1)]
        if len(parts) == 2 and parts[0] and parts[1]:
            s = f"{parts[1]} {parts[0]}"

    # Replace punctuation with spaces (keeps letters/numbers)
    s = re.sub(r"[^\w\s]", " ", s)

    # Collapse whitespace
    s = normalize_whitespace(s)

    return s

def author_key(raw):
    """
    Robust matching key: "<lastname> <firstinitials>"
    Example: "John Ronald Reuel Tolkien" -> "tolkien jrr"
    """
    s = standardize_name(raw)
    if not s:
        return ""

    parts = s.split()
    if len(parts) == 1:
        return parts[0]

    last = parts[-1]
    initials = "".join(p[0] for p in parts[:-1] if p)
    return f"{last} {initials}"

# %%
df_Authors_std = pd.DataFrame({
    "author_std": df_Authors["author_name"].apply(standardize_name)
})

# %%
df_Authors_std = df_Authors.copy()

df_Authors_std["author_std"] = (
    df_Authors_std["author_name"]
        .astype(str)
        .apply(standardize_name)
)

# %%
df_A_B_Code_std = df_A_B_Code.copy()

df_A_B_Code_std["author_std"] = (
    df_A_B_Code_std["Author(s)"]
        .astype(str)
        .apply(standardize_name)
)

# %%
# Reference list to match against (standardized author names)
choices = (
    df_A_B_Code_std["author_std"]
        .dropna()
        .astype(str)
        .tolist()
)

def match_std_name(name):
    if pd.isna(name) or str(name).strip() == "":
        return pd.Series([None, 0, None], index=["matched_author_std", "match_score", "matched_pos"])
    m = process.extractOne(str(name), choices, scorer=fuzz.WRatio)  
    return pd.Series([m[0], m[1], m[2]], index=["matched_author_std", "match_score", "matched_pos"])

df_Authors_std[["matched_author_std", "match_score", "matched_pos"]] = (
    df_Authors_std["author_std"].apply(match_std_name)
)

df_Authors_std["matched_df_index"] = df_Authors_std["matched_pos"].map(
    lambda p: df_A_B_Code_std.index[p] if pd.notna(p) else None
)

# %%
df_Authors_std_sorted = df_Authors_std.sort_values("match_score", ascending=False)
df_Authors_std_sorted[df_Authors_std_sorted["match_score"] >= 87]

# %%
#Do fuzzy matching for the authors in df_Authors to find the match in df_A_B_Code
#Obtain matching scores 
choices = (
    df_A_B_Code["Author(s)"]
        .dropna()
        .astype(str)
        .unique()
        .tolist()
)

def fuzzy_match_one(name):
    if pd.isna(name) or str(name).strip() == "":
        return pd.Series(
            [None, 0, None],
            index=["matched_author", "match_score", "matched_index"]
        )

    match, score, idx = process.extractOne(
        str(name),
        choices,
        scorer=fuzz.WRatio
    )

    return pd.Series(
        [match, score, idx],
        index=["matched_author", "match_score", "matched_index"]
    )

df_Authors[["matched_author", "match_score", "matched_index"]] = (
    df_Authors["author_name"].apply(fuzzy_match_one)
)

# %%
df_Authors_sorted = df_Authors.sort_values(
    by="match_score",
    ascending=False
)

# %%
df_Authors_sorted[df_Authors_sorted["match_score"] >= 87]
# Out:
#                              author_name short_id  \
# 28881  Zabala Iturriagagoitia, Jon Mikel    pza45
# 4541    Constantinescu, Lucretia Mariana   pco601
# 16701   Montero Ledezma de Hagerf, Paola  pmo1568
# 18088   Milczarek-Andrzejewska, Dominika   pmi438
# 20864     Prados de la Escosura, Leandro    ppr58
# ...                                  ...      ...
# 6159                 D'Alessio, Giovanni   pda166
# 23110               Soares, Ana Cristina   pso359
# 21115                Pattarin, Francesco   ppa329
# 11270               Holtemoeller, Oliver   pho140
# 11271               Holtemoeller, Oliver   pho140
#
#                                              institution share_pct  \
# 28881  Facultad de Ciencias Económicas y Empresariale...       NaN
# 4541   Departamentul Management, Marketing Facultatea...       NaN
# 16701              Konkurrensverket Government of Sweden       NaN
# 18088  Wydział Nauk Ekonomicznych Uniwersytet Warszawski       NaN
# 20864  Instituto Figuerola de Historia y Ciencias Soc...       50%
# ...                                                  ...       ...
# 6159                                      Banca d'Italia       NaN
# 23110                                  Banco de Portugal       NaN
# 21115  Centro Studi di Banca e Finanza (CEFIN) Dipart...       NaN
# 11270  Leibniz-Institut für Wirtschaftsforschung Hall...       50%
# 11271  Wirtschaftswissenschaftliche Fakultät Martin-L...       50%
#
#                           location repec_institution_id  \
# 28881  Bilbao/San Sebastián, Spain          edi:fsdeues
# 4541           Targoviste, Romania          edi:dmvalro
# 16701            Stockholm, Sweden          edi:kkvgvse
# 18088             Warszawa, Poland          edi:fesuwpl
# 20864                Madrid, Spain          edi:ilfhees
# ...                            ...                  ...
# 6159                   Roma, Italy          edi:bdigvit
# 23110             Lisboa, Portugal          edi:bdpgvpt
# 21115                Modena, Italy          edi:cbmodit
# 11270               Halle, Germany          edi:iwhhhde
# 11271    Halle-Wittenberg, Germany          edi:wwhalde
#
#                                    author_url  \
# 28881    https://ideas.repec.org/e/pza45.html
# 4541    https://ideas.repec.org/f/pco601.html
# 16701  https://ideas.repec.org/f/pmo1568.html
# 18088   https://ideas.repec.org/f/pmi438.html
# 20864    https://ideas.repec.org/e/ppr58.html
# ...                                       ...
# 6159    https://ideas.repec.org/e/pda166.html
# 23110   https://ideas.repec.org/f/pso359.html
# 21115   https://ideas.repec.org/f/ppa329.html
# 11270   https://ideas.repec.org/e/pho140.html
# 11271   https://ideas.repec.org/e/pho140.html
#
#                          matched_author  match_score  matched_index
# 28881  Zabala Iturriagagoitia Jon Mikel    98.461538          43110
# 4541    Constantinescu Lucretia Mariana    98.412698           5786
# 16701   Montero Ledezma de Hagerf Paola    98.412698          43411
# 18088   Milczarek-Andrzejewska Dominika    98.412698          33036
# 20864     Prados de la Escosura Leandro    98.305085          34363
# ...                                 ...          ...            ...
# 6159               DâAlessio Giovanni    87.179487          35507
# 23110               Torres Ana Cristina    87.179487          27702
# 21115              Cattabrini Francesco    87.179487          13201
# 11270               HoltemÃ¶ller Oliver    87.179487          43397
# 11271               HoltemÃ¶ller Oliver    87.179487          43397
#
# [3639 rows x 10 columns]

# %%
df2[df2["Title"]=="Mass Reproducibility and Replicability: A New Hope"]
